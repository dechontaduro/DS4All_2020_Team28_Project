# %%
import geopandas as gpd
import json

# %%
shape_filename = 'Cuencas_39_43_46'
geodf = gpd.read_file(f'..\data\shapes\{shape_filename}.shp')
geodf.to_file(f'..\data\shapes\{shape_filename}.gjson', driver = "GeoJSON")

# %%
with open(f'..\data\shapes\{shape_filename}.gjson') as geofile:
    j_file = json.load(geofile)

# %%
j_file
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'Macrocuenca': 39,
#     'Region Hid': 'Orinoco',
#     'Zona Hidro': 'Meta',
#     'Subzona Hi': 'R?o Guatiqu?a',
#     'NoIDEAM': None,
#     'Sm': 25.88,
#     'Area': 1525195.48},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-73.09666442999998, 3.587083103000054],
#       [-73.09708403799993, 3.586666828000034],
#       [-73.09750365499997, 3.586666827000045],
#       [-73.09750365399998, 3.586250070000063],
#       [-73.09833527199999, 3.58541655700003],
#       [-73.09833527299998, 3.585000033000028],
#       [-73.09833527299998, 3.583333495000033],
#       [-73.09916686799994, 3.583333494000044],
#       [-73.10064746699999, 3.582591493000052],
#       [-73.10083007199995, 3.582499980000023],
#       [-73.10250091499995, 3.583333253000034],
#       [-73.10354232899994, 3.582708359000037],
#       [-73.10416412799998, 3.581666474000031],
# ...

# %%
geodf.head()
# Out:
#    Macrocuenc       Region Hid      Zona Hidro  \
# 0          47          Orinoco        Guaviare
# 1           1  Magdalena Cauca           Cauca
# 2           2  Magdalena Cauca           Cauca
# 3           3  Magdalena Cauca  Alto Magdalena
# 4           4  Magdalena Cauca           Cauca
#
#                            Subzona Hi  NÂº IDEAM  Sm (%)   Area (ha)  \
# 0                       R?o Guayabero        NaN   22.26  7723341.71
# 1                          R?o Palac?        4.0   21.44    93254.34
# 2                           R?o Timba       15.0   41.11    48385.42
# 3                            R?o P?ez       17.0   40.32   519749.96
# 4  R?o Ot?n y otros directos al Cauca       24.0   31.71   122009.79
#
#                                             geometry
# 0  POLYGON ((-74.07570 1.97802, -74.07792 1.97833...
# 1  POLYGON ((-76.23000 2.55375, -76.22958 2.55250...
# 2  POLYGON ((-76.57640 3.12613, -76.57827 3.12405...
# ...
