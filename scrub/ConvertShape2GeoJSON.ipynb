# %%
import geopandas as gpd
import json

# %%
geodf = gpd.read_file(r'..\data\shapes\Macro_Cuencas.shp')
geodf.to_file(r'..\data\shapes\Macro_Cuencas.gjson', driver = "GeoJSON")

# %%
with open(r'..\data\shapes\Macro_Cuencas.gjson') as geofile:
    j_file = json.load(geofile)

# %%
j_file
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'Macrocuenc': 47,
#     'Region Hid': 'Orinoco',
#     'Zona Hidro': 'Guaviare',
#     'Subzona Hi': 'R?o Guayabero',
#     'NÂº IDEAM': None,
#     'Sm (%)': 22.26,
#     'Area (ha)': 7723341.71},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[-74.07570169299998, 1.978017112000032],
#       [-74.077919, 1.978333355000075],
#       [-74.07847609899994, 1.978412996000031],
#       [-74.08083343199996, 1.978749995000044],
#       [-74.08208465199993, 1.979166511000074],
#       [-74.08333588499994, 1.978749996000033],
#       [-74.08416747899997, 1.977916722000032],
#       [-74.08583068399997, 1.977500082000063],
#       [-74.08750152699997, 1.977083208000067],
#       [-74.08833312199994, 1.976250169000025],
#       [-74.08916473999994, 1.975833302000069],
# ...

# %%
geodf.head()
# Out:
#    Macrocuenc       Region Hid      Zona Hidro  \
# 0          47          Orinoco        Guaviare
# 1           1  Magdalena Cauca           Cauca
# 2           2  Magdalena Cauca           Cauca
# 3           3  Magdalena Cauca  Alto Magdalena
# 4           4  Magdalena Cauca           Cauca
#
#                            Subzona Hi  NÂº IDEAM  Sm (%)   Area (ha)  \
# 0                       R?o Guayabero        NaN   22.26  7723341.71
# 1                          R?o Palac?        4.0   21.44    93254.34
# 2                           R?o Timba       15.0   41.11    48385.42
# 3                            R?o P?ez       17.0   40.32   519749.96
# 4  R?o Ot?n y otros directos al Cauca       24.0   31.71   122009.79
#
#                                             geometry
# 0  POLYGON ((-74.07570 1.97802, -74.07792 1.97833...
# 1  POLYGON ((-76.23000 2.55375, -76.22958 2.55250...
# 2  POLYGON ((-76.57640 3.12613, -76.57827 3.12405...
# ...
