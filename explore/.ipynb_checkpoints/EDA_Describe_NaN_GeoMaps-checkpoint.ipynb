# %% [markdown]
# ![ds4a_colombia.svg](attachment:ds4a_colombia.svg)

# %% [markdown]
# # Impacto de la deforestación en el regimen de caudales de los rios en Colombia (TEAM 28)

# %% [markdown]
# ## EDA - Describe, NaN, GeoMaps

# %% [markdown]
# ### Librerias

# %%
import numpy as np 
import pandas as pd

import geopandas as gpd
import geoplot as geop
import descartes as dsc

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Files reading

# %%
fp = '../data/shapes/Basins_Colombia.shp'
data_geo = gpd.read_file(fp, encoding = 'utf-8')

fp_est = '../data/shapes/CNE_IDEAM CNE.shp'
data_geo_est = gpd.read_file(fp_est, encoding = 'utf-8')

# %%
print('Tipo de objeto cuencas : ', type(data_geo), '\n')
print('Tamaño del objeto cuencas: ', data_geo.shape, '\n')
print('Columnas del objeto cuencas: ', data_geo.columns, '\n')
print(data_geo.head)

print('Tipo de objeto estaciones: ', type(data_geo_est), '\n')
print('Tamaño del objeto estaciones: ', data_geo_est.shape, '\n')
print('Columnas del objeto estaciones: ', data_geo_est.columns, '\n')
print(data_geo_est.head)
# Out:
# Tipo de objeto cuencas :  <class 'geopandas.geodataframe.GeoDataFrame'>
#
# Tamaño del objeto cuencas:  (316, 11)
#
# Columnas del objeto cuencas:  Index(['cod_ah', 'cod_szh', 'cod_zh', 'nom_ah', 'nom_szh', 'nom_zh',
#        'objectid_1', 'ruleid', 'shape_area', 'shape_leng', 'geometry'],
#       dtype='object')
#
# <bound method NDFrame.head of      cod_ah  cod_szh  cod_zh           nom_ah  \
# 0       1.0   1701.0    17.0           Caribe
# 1       1.0   1702.0    17.0           Caribe
# 2       1.0   1703.0    17.0           Caribe
# 3       2.0   2602.0    26.0  Magdalena Cauca
# 4       2.0   2632.0    26.0  Magdalena Cauca
# ..      ...      ...     ...              ...
# 311     3.0   3516.0    35.0          Orinoco
# 312     1.0   1117.0    11.0           Caribe
# 313     1.0   1509.0    15.0           Caribe
# 314     5.0   5310.0    53.0         Pacifico
# 315     5.0   5309.0    53.0         Pacifico
#
#                                    nom_szh                     nom_zh  \
# 0                               San Andres               Islas Caribe
# 1                              Providencia               Islas Caribe
# 2                    Roncador y Quitasue?o               Islas Caribe
# 3                               R?o Palac?                      Cauca
# 4            R?os Guabas,Sabaletas y Sonso                      Cauca
# ..                                     ...                        ...
# 311                           Lago de Tota                       Meta
# 312  R?o Cabi y otros Directos Atrato (md)            Atrato - Dari?n
# 313   Rio Guachaca - Mendiguaca y Buritaca           Caribe - Guajira
# 314                          R?o Anchicay?  Tapaje - Dagua - Directos
# 315     R?os Cajambre - Mayorqu?n - Raposo  Tapaje - Dagua - Directos
#
#      objectid_1  ruleid  shape_area  shape_leng  \
# 0           1.0     2.0    0.002232    0.358011
# 1           2.0     2.0    0.001842    0.294393
# 2           3.0     2.0    0.002260    0.341056
# 3           4.0     3.0    0.075834    1.709663
# 4           8.0     3.0    0.045246    1.027300
# ..          ...     ...         ...         ...
# 311       310.0     4.0    0.018405    0.783935
# 312       311.0     2.0    0.038112    1.101357
# 313       312.0     2.0    0.056655    1.137513
# 314       313.0     5.0    0.103941    1.943043
# 315       314.0     5.0    0.162105    2.425948
#
#                                               geometry
# 0    POLYGON ((-81.70399 12.59487, -81.70394 12.594...
# 1    MULTIPOLYGON (((-81.37077 13.39450, -81.37077 ...
# 2    MULTIPOLYGON (((-81.10900 14.46640, -81.12305 ...
# 3    POLYGON ((-76.23000 2.55375, -76.22958 2.55250...
# 4    POLYGON ((-76.10625 3.82250, -76.10542 3.82167...
# ..                                                 ...
# 311  POLYGON ((-72.84084 5.64667, -72.84084 5.64542...
# 312  POLYGON ((-76.45529 5.69545, -76.45541 5.69583...
# 313  POLYGON ((-73.70112 11.26024, -73.70117 11.260...
# 314  POLYGON ((-76.67667 3.46417, -76.67709 3.46417...
# 315  POLYGON ((-76.73417 3.33083, -76.73417 3.33065...
#
# [316 rows x 11 columns]>
# Tipo de objeto estaciones:  <class 'geopandas.geodataframe.GeoDataFrame'>
#
# Tamaño del objeto estaciones:  (4461, 21)
#
# Columnas del objeto estaciones:  Index(['OBJECTID', 'CODIGO', 'nombre', 'CATEGORIA', 'TECNOLOGIA', 'ESTADO',
#        'FECHA_INST', 'altitud', 'latitud', 'longitud', 'DEPARTAMEN',
#        'MUNICIPIO', 'AREA_OPERA', 'AREA_HIDRO', 'ZONA_HIDRO', 'observacio',
#        'CORRIENTE', 'FECHA_SUSP', 'SUBZONA_HI', 'ENTIDAD', 'geometry'],
#       dtype='object')
#
# <bound method NDFrame.head of       OBJECTID      CODIGO                               nombre  \
# 0            1    52057100           RUMICHACA - AUT [52057100]
# 1            2    52055170         LA JOSEFINA - AUT [52055170]
# 2            3    52055220          EL PARAISO - AUT [52055220]
# 3            4    44015070           EL PEPINO - AUT [44015070]
# 4            5    48015040       PUERTO NARINO - AUT [48015040]
# ...        ...         ...                                  ...
# 4456      4457  3503500169  ESTACIÓN ISOTÓPICA VILLAVICENCIO_02
# 4457      4458  1117500170         ESTACIÓN ISOTÓPICA QUIBDÓ_01
# 4458      4459  5601500171   ESTACIÓN ISOTÓPICA BAHIA SOLANO_01
# 4459      4460  3503500168  ESTACIÓN ISOTÓPICA VILLAVICENCIO_01
# 4460      4461  5311000162   ESTACIÓN ISOTÓPICA BUENAVENTURA_01
#
#                    CATEGORIA                 TECNOLOGIA      ESTADO  \
# 0               Limnigráfica  Automática con Telemetría      Activa
# 1        Climática Principal  Automática con Telemetría      Activa
# 2        Climática Principal  Automática con Telemetría      Activa
# 3        Climática Principal  Automática con Telemetría      Activa
# 4        Climática Principal  Automática con Telemetría      Activa
# ...                      ...                        ...         ...
# 4456  Meteorológica Especial               Convencional  Suspendida
# 4457  Meteorológica Especial               Convencional      Activa
# 4458  Meteorológica Especial               Convencional      Activa
# 4459  Meteorológica Especial               Convencional      Activa
# 4460           Pluviométrica               Convencional      Activa
#
#                    FECHA_INST  altitud   latitud   longitud  ...  \
# 0     2016/11/15 00:00:00.000     2582  0.813786 -77.661978  ...
# 1     2005/12/10 00:00:00.000     2450  0.930306 -77.491194  ...
# 2     2004/03/01 00:00:00.000     3120  1.070611 -77.636889  ...
# 3     2005/11/11 00:00:00.000      760  1.082889 -76.667111  ...
# 4     2005/07/19 00:00:00.000      158 -3.780306 -70.362639  ...
# ...                       ...      ...       ...        ...  ...
# 4456  2015/07/01 00:00:00.000     1175  4.131017 -73.689044  ...
# 4457  2019/08/05 00:00:00.000       75  5.690556 -76.643778  ...
# 4458  2019/08/19 00:00:00.000        4  6.223333 -77.404444  ...
# 4459  2014/12/01 00:00:00.000      444  4.137500 -73.625000  ...
# 4460  2019/08/08 00:00:00.000       28  3.820111 -76.992389  ...
#
#                  MUNICIPIO                                         AREA_OPERA  \
# 0                  Ipiales                Area Operativa 07 - Nariño-Putumayo
# 1                Contadero                Area Operativa 07 - Nariño-Putumayo
# 2                Túquerres                Area Operativa 07 - Nariño-Putumayo
# 3                    Mocoa                Area Operativa 07 - Nariño-Putumayo
# 4            Puerto Nariño  Area Operativa 11 - Cundinamarca-Amazonas-San ...
# ...                    ...                                                ...
# 4456         Villavicencio          Area Operativa 03 - Meta-Guaviare-Guainía
# 4457                Quibdó                Area Operativa 01 - Antioquia-Chocó
# 4458  Bahía Solano (Mutis)                Area Operativa 01 - Antioquia-Chocó
# 4459         Villavicencio          Area Operativa 03 - Meta-Guaviare-Guainía
# 4460          Buenaventura             Area Operativa 09 - Cauca-Valle-Caldas
#
#      AREA_HIDRO                 ZONA_HIDRO  \
# 0      Pacifico                      Patía
# 1      Pacifico                      Patía
# 2      Pacifico                      Patía
# 3      Amazonas                    Caquetá
# 4      Amazonas        Amazonas - Directos
# ...         ...                        ...
# 4456    Orinoco                       Meta
# 4457     Caribe            Atrato - Darién
# 4458   Pacifico        Pacífico - Directos
# 4459    Orinoco                       Meta
# 4460   Pacifico  Tapaje - Dagua - Directos
#
#                                              observacio CORRIENTE  \
# 0                                                  None  Guaitara
# 1                                                  None  Guaitara
# 2                                                  None  Guaitara
# 3                                                  None  Guaitara
# 4                                                  None  Amazonas
# ...                                                 ...       ...
# 4456  Creacion Estacion por Solicitud de Hidrologia ...         0
# 4457  Creacion Estacion por Solicitud de Hidrologia ...         0
# 4458  Creacion Estacion por Solicitud de Hidrologia ...         0
# 4459  Creacion Estacion por Solicitud de Hidrologia ...         0
# 4460  Creacion Estacion por Solicitud de Hidrologia ...         0
#
#                    FECHA_SUSP                             SUBZONA_HI  \
# 0                        None                           Río Guáitara
# 1                        None                           Río Guáitara
# 2                        None                           Río Guáitara
# 3                        None                           Alto Caqueta
# 4                        None             Directos Río Amazonas (mi)
# ...                       ...                                    ...
# 4456  2020/05/26 14:54:41.000                          Río Guatiquía
# 4457                     None  Río Cabi y otros Directos Atrato (md)
# 4458                     None      Directos Pacifico Frontera Panamá
# 4459                     None                          Río Guatiquía
# 4460                     None    Dagua - Buenaventura - Bahia Málaga
#
#                                                 ENTIDAD  \
# 0     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 2     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 3     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4     INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# ...                                                 ...
# 4456  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4457  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4458  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4459  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4460  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
#
#                                     geometry
# 0     POINT Z (-77.66198 0.81379 2582.00000)
# 1     POINT Z (-77.49119 0.93031 2450.00000)
# 2     POINT Z (-77.63689 1.07061 3120.00000)
# 3      POINT Z (-76.66711 1.08289 760.00000)
# 4     POINT Z (-70.36264 -3.78031 158.00000)
# ...                                      ...
# 4456  POINT Z (-73.68904 4.13102 1175.00000)
# 4457    POINT Z (-76.64378 5.69056 75.00000)
# 4458     POINT Z (-77.40444 6.22333 4.00000)
# 4459   POINT Z (-73.62500 4.13750 444.00000)
# 4460    POINT Z (-76.99239 3.82011 28.00000)
#
# [4461 rows x 21 columns]>

# %%
print(data_geo_est['CATEGORIA'].unique())

data_geo_est.head(5)
# Out:
# ['Limnigráfica' 'Climática Principal' 'Mareográfica' 'Pluviográfica'
#  'Climática Ordinaria' 'Agrometeorológica' 'Limnimétrica' 'Pluviométrica'
#  'Meteorológica Especial' 'Sinóptica Principal' 'Sinóptica Secundaria'
#  'Radio Sonda']
#    OBJECTID    CODIGO                          nombre            CATEGORIA  \
# 0         1  52057100      RUMICHACA - AUT [52057100]         Limnigráfica
# 1         2  52055170    LA JOSEFINA - AUT [52055170]  Climática Principal
# 2         3  52055220     EL PARAISO - AUT [52055220]  Climática Principal
# 3         4  44015070      EL PEPINO - AUT [44015070]  Climática Principal
# 4         5  48015040  PUERTO NARINO - AUT [48015040]  Climática Principal
#
#                   TECNOLOGIA  ESTADO               FECHA_INST  altitud  \
# 0  Automática con Telemetría  Activa  2016/11/15 00:00:00.000     2582
# 1  Automática con Telemetría  Activa  2005/12/10 00:00:00.000     2450
# 2  Automática con Telemetría  Activa  2004/03/01 00:00:00.000     3120
# 3  Automática con Telemetría  Activa  2005/11/11 00:00:00.000      760
# 4  Automática con Telemetría  Activa  2005/07/19 00:00:00.000      158
#
#     latitud   longitud  ...      MUNICIPIO  \
# 0  0.813786 -77.661978  ...        Ipiales
# 1  0.930306 -77.491194  ...      Contadero
# 2  1.070611 -77.636889  ...      Túquerres
# 3  1.082889 -76.667111  ...          Mocoa
# 4 -3.780306 -70.362639  ...  Puerto Nariño
#
#                                           AREA_OPERA AREA_HIDRO  \
# 0                Area Operativa 07 - Nariño-Putumayo   Pacifico
# 1                Area Operativa 07 - Nariño-Putumayo   Pacifico
# 2                Area Operativa 07 - Nariño-Putumayo   Pacifico
# 3                Area Operativa 07 - Nariño-Putumayo   Amazonas
# 4  Area Operativa 11 - Cundinamarca-Amazonas-San ...   Amazonas
#
#             ZONA_HIDRO observacio CORRIENTE FECHA_SUSP  \
# 0                Patía       None  Guaitara       None
# 1                Patía       None  Guaitara       None
# 2                Patía       None  Guaitara       None
# 3              Caquetá       None  Guaitara       None
# 4  Amazonas - Directos       None  Amazonas       None
#
#                    SUBZONA_HI  \
# 0                Río Guáitara
# 1                Río Guáitara
# 2                Río Guáitara
# 3                Alto Caqueta
# 4  Directos Río Amazonas (mi)
#
#                                              ENTIDAD  \
# 0  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 1  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 2  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 3  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
# 4  INSTITUTO DE HIDROLOGIA METEOROLOGIA Y ESTUDIO...
#
#                                  geometry
# 0  POINT Z (-77.66198 0.81379 2582.00000)
# 1  POINT Z (-77.49119 0.93031 2450.00000)
# 2  POINT Z (-77.63689 1.07061 3120.00000)
# 3   POINT Z (-76.66711 1.08289 760.00000)
# 4  POINT Z (-70.36264 -3.78031 158.00000)
#
# [5 rows x 21 columns]

# %%
data_geo.head(5)
# Out:
#    cod_ah  cod_szh  cod_zh           nom_ah                        nom_szh  \
# 0     1.0   1701.0    17.0           Caribe                     San Andres
# 1     1.0   1702.0    17.0           Caribe                    Providencia
# 2     1.0   1703.0    17.0           Caribe          Roncador y Quitasue?o
# 3     2.0   2602.0    26.0  Magdalena Cauca                     R?o Palac?
# 4     2.0   2632.0    26.0  Magdalena Cauca  R?os Guabas,Sabaletas y Sonso
#
#          nom_zh  objectid_1  ruleid  shape_area  shape_leng  \
# 0  Islas Caribe         1.0     2.0    0.002232    0.358011
# 1  Islas Caribe         2.0     2.0    0.001842    0.294393
# 2  Islas Caribe         3.0     2.0    0.002260    0.341056
# 3         Cauca         4.0     3.0    0.075834    1.709663
# 4         Cauca         8.0     3.0    0.045246    1.027300
#
#                                             geometry
# 0  POLYGON ((-81.70399 12.59487, -81.70394 12.594...
# 1  MULTIPOLYGON (((-81.37077 13.39450, -81.37077 ...
# 2  MULTIPOLYGON (((-81.10900 14.46640, -81.12305 ...
# 3  POLYGON ((-76.23000 2.55375, -76.22958 2.55250...
# 4  POLYGON ((-76.10625 3.82250, -76.10542 3.82167...

# %% [markdown]
# ### Geo Maps

# %%
#fig, ax = plt.subplots(figsize=(10,10))
#mapa = data_geo.plot(ax = ax)

data_geo_est_climappal = data_geo_est[data_geo_est['CATEGORIA'] == 'Climática Principal'].reset_index()
data_geo_est_climaord = data_geo_est[data_geo_est['CATEGORIA'] == 'Climática Ordinaria'].reset_index()
data_geo_est_lmm = data_geo_est[data_geo_est['CATEGORIA'] == 'Limnimétrica'].reset_index()
data_geo_est_lmg = data_geo_est[data_geo_est['CATEGORIA'] == 'Limnigráfica'].reset_index()
data_geo_est_plm = data_geo_est[data_geo_est['CATEGORIA'] == 'Pluviométrica'].reset_index()
data_geo_est_plg = data_geo_est[data_geo_est['CATEGORIA'] == 'Pluviográfica'].reset_index()

fig, ax = plt.subplots(figsize=(15,15))
ax.set_title('Cuencas hidrográficas Colombia')
mapa_base = data_geo.plot(ax = ax, color = 'white', edgecolor='green')
mapa_base = data_geo_est_climappal.plot(ax = mapa_base, marker = 'o', color = 'red', 
                                        markersize = 5)
mapa_final = data_geo_est_climaord.plot(ax = mapa_base, marker = 'o', color = 'blue', 
                                        markersize = 5)
mapa_final = data_geo_est_lmm.plot(ax = mapa_base, marker = 'o', color = 'lightcoral', 
                                   markersize = 5)
mapa_final = data_geo_est_lmg.plot(ax = mapa_base, marker = 'o', color = 'fuchsia', 
                                   markersize = 5)
mapa_final = data_geo_est_plm.plot(ax = mapa_base, marker = 'o', color = 'mediumseagreen', 
                                   markersize = 5)
mapa_final = data_geo_est_plg.plot(ax = mapa_base, marker = 'o', color = 'orangered', 
                                   markersize = 5)

# %%
data_geo_join = gpd.sjoin(data_geo, data_geo_est)

#print(data_geo.columns)
#print(data_geo_est.columns)
#print(data_geo_join.columns)

#print(data_geo_join.shape)
#print(data_geo_join.head())

df_count_est = pd.pivot_table(data_geo_join, index = ['objectid_1'], 
                              aggfunc = {'OBJECTID':'count'}).reset_index()

df_count_est.columns = ['objectid_1', 'Qty_stations']

df_count_est
# Out:
#      objectid_1  Qty_stations
# 0           1.0             8
# 1           2.0             8
# 2           4.0            12
# 3           5.0             7
# 4           6.0            17
# ..          ...           ...
# 244       310.0            17
# 245       311.0             7
# 246       312.0            10
# 247       313.0             1
# 248       314.0             2
#
# [249 rows x 2 columns]

# %% [markdown]
# ### Heat Geo Map

# %%
temp_df = pd.merge(data_geo, df_count_est, on = ['objectid_1'], how = 'inner')
temp_df['Qty_stations'].fillna(0, inplace = True)

max_Qty_stations = float(temp_df['Qty_stations'].max())

temp_df['perc'] = 0
temp_df['perc'] = (temp_df['Qty_stations'].div(max_Qty_stations) * 100).round(0)

fig, ax = plt.subplots(nrows = 1, figsize=(15,15))
titulo = 'Heat Map - Stations in Bains'
ax.set_title(titulo)
mapa1 = temp_df.plot(column = 'perc', cmap = 'Blues', linewidth = 0.8, ax = ax, 
                     edgecolor = '0.8')
